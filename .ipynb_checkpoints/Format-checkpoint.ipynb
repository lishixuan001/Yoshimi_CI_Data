# %%
import pandas as pd
import numpy as np

from os import listdir
from os.path import join

# %%
data_type = "0304"
base_dir = f"./{data_type}/"

# %%
insertions = {
    0: ["Intercept", ""],
    1: ["Age", ""],
    2: ["Diabete", ""],
    5: ["BMI", ""],
    6: ["Smoke", ""],
    8: ["Country", ""],
    10: ["Race", ""],
    14: ["Education", ""],
    20: ["Gender", ""],
    22: ["Activity", ""]
}

# %%
columns = ["Variables", "Confidence Interval"]

# %%
for file_name in listdir(base_dir):
    assert file_name.endswith("csv")
    file_name = join(base_dir, file_name)
    df = pd.read_csv(file_name)
    data = []
    for i in range(df.shape[0]):
        if i in insertions.keys():
            data.append(insertions[i])
        line = df.iloc[i]
        name = line["Unnamed: 0"]
        estm = round(float(line["Estimate"]), 3)
        lb = round(float(line['LB']), 3)
        ub = round(float(line['UB']), 3)
        dataline = [name, f"{estm} ({lb}~{ub})",]
        data.append(dataline)
    form = pd.DataFrame(data, index=None, columns=columns)
    form.to_csv(f"./Result_{data_type}/{file_name}")

# %%
form
# Out:
#                                   Variables      Confidence Interval
# 0                                 Intercept
# 1                               (Intercept)   44.071 (20.358~67.784)
# 2                                       Age
# 3                                       age      0.107 (0.079~0.134)
# 4                                   Diabete
# 5                           diabPre-diabete    8.09 (-15.333~31.512)
# 6                               diabdiabete   10.74 (-12.956~34.435)
# 7                               diabUnknown  11.508 (-11.868~34.883)
# 8                                       BMI
# 9                                       bmi      0.379 (0.301~0.456)
# 10                                    Smoke
# 11                               smokeSmoke      1.965 (0.597~3.332)
# 12                             smokeUnknown      0.55 (-0.528~1.628)
# 13                                  Country
# 14                            countryMexico    -1.005 (-3.584~1.574)
# 15                              countryU.S.     0.309 (-1.489~2.106)
# 16                                     Race
# 17                   raceNon-Hispanic Black     1.036 (-0.719~2.791)
# 18                     raceMexican American    -1.575 (-3.091~-0.06)
# 19                       raceOther Hispanic    -0.016 (-3.216~3.185)
# 20  raceOther Race - Including Multi-Racial      2.856 (0.089~5.623)
# 21                                Education
# 22                               education2     0.004 (-1.726~1.735)
# 23                               education3      2.109 (0.503~3.715)
# 24                               education4      3.233 (1.614~4.852)
# 25                               education5      2.707 (0.946~4.468)
# 26                               education7  -1.333 (-17.877~15.211)
# 27                               education9   1.869 (-14.694~18.433)
# 28                                   Gender
# 29                             genderFemale      2.193 (1.261~3.125)
# 30                                sedentary   -7.93 (-14.228~-1.632)
# 31                                 Activity
# 32                          activitycCounts      -0.0 (-0.004~0.004)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Estimate', 'Std. Error', 't value', 'Pr(>|t|)', 'LB',
#        'UB'],
#       dtype='object')
